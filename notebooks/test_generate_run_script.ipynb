# %%
bias = [False, True]
lrs = [0.01, 0.001, 0.0001]
hidden_dims = [128, 256, 512]
models = ['transe', 'distmult', 'complex', 'rotate']
datasets = ['cn15k', 'nl27k', 'ppi5k']
confi_score_functions = ['logi', 'rect']
fc_layers = ['l1', 'l3', 'none']


for b in bias:
    for lr in lrs:
        for hidden_dim in hidden_dims:
            for model in models:
                for dataset in datasets:
                    for confi in confi_score_functions:
                        for fc in fc_layers:
                            if b:
                                print(f"nohup python -u src/ukge/train_unc_baseline.py --model {model} --dataset {dataset} --confidence_score_function {confi} --fc_layers {fc} --bias --hidden_dim {hidden_dim} --lr {lr} --topk &> logs/unc_{model}_{dataset}_confi_{confi}_fc_{fc}_bias_{b}_lr_{lr}_dim_{hidden_dim}.log & ")
                            else: 
                                print(f"nohup python -u src/ukge/train_unc_baseline.py --model {model} --dataset {dataset} --confidence_score_function {confi} --fc_layers {fc} --hidden_dim {hidden_dim} --lr {lr} --topk &> logs/unc_{model}_{dataset}_confi_{confi}_fc_{fc}_bias_{b}_lr_{lr}_dim_{hidden_dim}.log & ")
# Out:
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_128.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 256 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_256.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l3_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers none --hidden_dim 512 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_none_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l1 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l1_bias_False_lr_0.01_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l3 --hidden_dim 512 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l3_bias_False_lr_0.01_dim_512.log &
# ...
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_nl27k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_nl27k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_cn15k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_cn15k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_nl27k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_nl27k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_none_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l1_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l3_bias_True_lr_0.0001_dim_512.log &
# nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 512 --lr 0.0001 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_none_bias_True_lr_0.0001_dim_512.log &

# %%
b = True
lr = 0.01
hidden_dim = 128

models = ['transe', 'distmult', 'complex', 'rotate']
datasets = ['cn15k', 'nl27k', 'ppi5k']
confi_score_functions = ['logi', 'rect']
fc_layers = ['l1', 'l3', 'none']
for model in models:
    for dataset in datasets:
        for confi in confi_score_functions:
            for fc in fc_layers:
                print(f"CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model {model} --dataset {dataset} --confidence_score_function {confi} --fc_layers {fc} --bias --hidden_dim {hidden_dim} --lr {lr} --topk &> logs/unc_{model}_{dataset}_confi_{confi}_fc_{fc}_bias_{b}_lr_{lr}_dim_{hidden_dim}.log & ")
# Out:
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset cn15k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_cn15k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_nl27k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model transe --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_transe_ppi5k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset cn15k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_cn15k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_nl27k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model distmult --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_distmult_ppi5k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset cn15k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_cn15k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_nl27k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model complex --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_complex_ppi5k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset cn15k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_cn15k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset nl27k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_nl27k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function logi --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_logi_fc_none_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l1 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l1_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers l3 --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_l3_bias_True_lr_0.01_dim_128.log &
# CUDA_VISIBLE_DEVICES=3 nohup python -u src/ukge/train_unc_baseline.py --model rotate --dataset ppi5k --confidence_score_function rect --fc_layers none --bias --hidden_dim 128 --lr 0.01 --topk &> logs/unc_rotate_ppi5k_confi_rect_fc_none_bias_True_lr_0.01_dim_128.log &
